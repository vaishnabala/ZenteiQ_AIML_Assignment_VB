# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnabala/ZenteiQ_AIML_Assignment_VB/blob/main/Vaishnavi_Balaji_ZenteiQ_Application_AI_ML_Role.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instal in maxtext(CPU runtime) Realised that is not necessary

# %%
#pip install maxtext

# %% [markdown]
# Install uv

# %%
pip install uv

# %% [markdown]
# Reason for installing uv:
# *   it's faster than pip
# *   It's written on Rust

# %% [markdown]
# Next, Clone Maxtext as its CPU runtime type

# %%
# !git clone https://github.com/AI-Hypercomputer/maxtext.git
# %cd maxtext
# Out:
# Cloning into 'maxtext'...
# remote: Enumerating objects: 97903, done.
# remote: Counting objects: 100% (535/535), done.
# remote: Compressing objects: 100% (255/255), done.
# remote: Total 97903 (delta 343), reused 428 (delta 280), pack-reused 97368 (from 2)
# Receiving objects: 100% (97903/97903), 449.25 MiB | 10.81 MiB/s, done.
# Resolving deltas: 100% (71844/71844), done.
# /content/maxtext/maxtext

# %%
# !uv pip install --system -e . --resolution=lowest
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 1 package in 1.05s
# Prepared 1 package in 3ms
# Uninstalled 1 package in 0.79ms
# Installed 1 package in 2ms
#  - maxtext==0.2.3 (from file:///content/maxtext)
#  + maxtext==0.2.3 (from file:///content/maxtext/maxtext)

# %% [markdown]
# /content/maxtext/src/maxtext/configs/types.py
#
# The above link has a class DatasetType

# %% [markdown]
# Task 2:

# %%
# !python3 -m maxtext.trainers.pre_train.train \
    model_name=qwen3-0.6b \
    steps=50 \
    dataset_type=synthetic \
    base_output_directory=/content/metrics/cpu/base \
    run_name=qwen_0.6b_cpu
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/content/maxtext/maxtext/src/maxtext/__init__.py", line 38, in <module>
#     from maxtext.configs import pyconfig
#   File "/content/maxtext/maxtext/src/maxtext/configs/pyconfig.py", line 32, in <module>
#     from maxtext.configs import pyconfig_deprecated
#   File "/content/maxtext/maxtext/src/maxtext/configs/pyconfig_deprecated.py", line 36, in <module>
#     from maxtext.utils import max_utils
#   File "/content/maxtext/maxtext/src/maxtext/utils/max_utils.py", line 45, in <module>
#     from maxtext.utils import elastic_utils
#   File "/content/maxtext/maxtext/src/maxtext/utils/elastic_utils.py", line 23, in <module>
#     import pathwaysutils
# ModuleNotFoundError: No module named 'pathwaysutils'

# %%
# !uv pip install --system pathwaysutils
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 40 packages in 922ms
# Prepared 3 packages in 5.87s
# Uninstalled 2 packages in 187ms
# Installed 3 packages in 42ms
#  - jax==0.7.2
#  + jax==0.10.2
#  - jaxlib==0.7.2
#  + jaxlib==0.10.2
#  + pathwaysutils==0.1.9

# %%
# !uv pip install --system --upgrade jax flax
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 29 packages in 317ms
# Prepared 10 packages in 1.99s
# Uninstalled 10 packages in 153ms
# Installed 10 packages in 56ms
#  - absl-py==1.4.0
#  + absl-py==2.4.0
#  - aiofiles==24.1.0
#  + aiofiles==25.1.0
#  - flax==0.11.2
#  + flax==0.12.7
#  - fsspec==2025.3.0
#  + fsspec==2026.6.0
#  - msgpack==1.1.2
#  + msgpack==1.2.1
#  - numpy==2.0.2
#  + numpy==2.4.6
#  - protobuf==5.29.6
#  + protobuf==7.35.1
#  - psutil==5.9.5
#  + psutil==7.2.2
#  - rich==13.9.4
#  + rich==15.0.0
#  - scipy==1.16.3
#  + scipy==1.18.0

# %%
# Install the missing JAX quantization library
# !uv pip install --system qwix
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 30 packages in 182ms
# Prepared 1 package in 44ms
# Installed 1 package in 2ms
#  + qwix==0.1.7

# %%
# Install the missing Google AQT quantization framework
# !uv pip install --system aqtp
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 30 packages in 287ms
# Prepared 1 package in 123ms
# Installed 1 package in 14ms
#  + aqtp==0.9.0

# %%
# Install the missing OpenXLA Tokamax custom kernel library
# !uv pip install --system tokamax
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 43 packages in 276ms
# Prepared 6 packages in 98ms
# Uninstalled 1 package in 8ms
# Installed 6 packages in 10ms
#  + einshape==1.0
#  + jaxtyping==0.3.11
#  + tensorboardx==2.6.5
#  + tokamax==0.0.12
#  - typeguard==4.5.2
#  + typeguard==2.13.3
#  + wadler-lindig==0.1.7

# %%
# Install the missing Google Accelerator performance tracker library
# !uv pip install --system ml-goodput-measurement
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 30 packages in 660ms
# Prepared 2 packages in 36ms
# Uninstalled 1 package in 2ms
# Installed 2 packages in 3ms
#  - grpcio-status==1.71.2
#  + grpcio-status==1.81.0
#  + ml-goodput-measurement==0.2.0

# %%
# !uv pip install --system drjax
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 8 packages in 225ms
# Prepared 1 package in 20ms
# Installed 1 package in 1ms
#  + drjax==0.2.0

# %%
# !uv pip install --system ml_collections
# Out:
# Using Python 3.12.13 environment at: /usr
# Checked 1 package in 92ms

# %%
# !python3 -m maxtext.trainers.pre_train.train \
    model_name=qwen3-0.6b \
    steps=50 \
    dataset_type=synthetic \
    attention=dot_product \
    skip_jax_distributed_system=True \
    base_output_directory=/content/metrics/cpu/base \
    run_name=qwen_0.6b_cpu
# Out:
# 2026-06-20 15:50:23.405818: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-06-20 15:50:25.374628: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-06-20 15:50:29.026324: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# [transformers] DeepseekV32Config got `key=rope_scaling` in kwargs but hasn't set it as attribute. For RoPE standardization you need to set `self.rope_parameters` in model's config.
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# ...

# %% [markdown]
# Executed the above code, it automatically stopped after it says "Waiting for step 0 to finish before checkpoint... so Im moving to GPU run time

# %%
# !pip install uv

# %%
# !git clone https://github.com/AI-Hypercomputer/maxtext.git
# %cd maxtext
# Out:
# Cloning into 'maxtext'...
# remote: Enumerating objects: 97903, done.
# remote: Counting objects: 100% (542/542), done.
# remote: Compressing objects: 100% (255/255), done.
# remote: Total 97903 (delta 350), reused 435 (delta 287), pack-reused 97361 (from 2)
# Receiving objects: 100% (97903/97903), 449.28 MiB | 18.35 MiB/s, done.
# Resolving deltas: 100% (71832/71832), done.
# /content/maxtext

# %%
# !uv pip install --system pathwaysutils qwix aqtp tokamax ml-goodput-measurement drjax ml_collections
# !uv pip install --system --upgrade jax[cuda12] flax -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !uv pip install --system -e . --resolution=lowest
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 77 packages in 701ms
# Prepared 1 package in 15ms
# Uninstalled 1 package in 1ms
# Installed 1 package in 5ms
#  - grpcio-status==1.71.2
#  + grpcio-status==1.81.0
# Using Python 3.12.13 environment at: /usr
# Resolved 44 packages in 103ms
# Checked 44 packages in 0.78ms
# Using Python 3.12.13 environment at: /usr
# error: /content does not appear to be a Python project, as neither `pyproject.toml` nor `setup.py` are present in the directory

# %%
# Force reinstall JAX with CUDA 12 support
# !uv pip install --system --force-reinstall jax[cuda12] -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 21 packages in 78ms
# Prepared 21 packages in 1ms
# Uninstalled 21 packages in 103ms
# Installed 21 packages in 76ms
#  ~ jax==0.10.2
#  ~ jax-cuda12-pjrt==0.10.2
#  ~ jax-cuda12-plugin==0.10.2
#  ~ jaxlib==0.10.2
#  ~ ml-dtypes==0.5.4
#  ~ numpy==2.4.6
#  ~ nvidia-cublas-cu12==12.9.2.10
#  ~ nvidia-cuda-cccl-cu12==12.9.27
#  ~ nvidia-cuda-cupti-cu12==12.9.79
#  ~ nvidia-cuda-nvcc-cu12==12.9.86
#  ~ nvidia-cuda-nvrtc-cu12==12.9.86
#  ~ nvidia-cuda-runtime-cu12==12.9.79
#  ~ nvidia-cudnn-cu12==9.23.2.1
#  ~ nvidia-cufft-cu12==11.4.1.4
#  ~ nvidia-cusolver-cu12==11.7.5.82
#  ~ nvidia-cusparse-cu12==12.5.10.65
#  ~ nvidia-nccl-cu12==2.30.7
#  ~ nvidia-nvjitlink-cu12==12.9.86
#  ~ nvidia-nvshmem-cu12==3.7.0
#  ~ opt-einsum==3.4.0
#  ~ scipy==1.18.0

# %%
# !python3 -m maxtext.trainers.pre_train.train \
    model_name=qwen3-0.6b \
    steps=50 \
    dataset_type=synthetic \
    attention=dot_product \
    per_device_batch_size=1 \
    max_target_length=512 \
    enable_checkpointing=False \
    save_checkpoint_on_completion=False \
    skip_jax_distributed_system=True \
    base_output_directory=/content/metrics/gpu/base \
    run_name=qwen_0.6b_gpu
# Out:
# 2026-06-20 16:26:53.139949: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [transformers] DeepseekV32Config got `key=rope_scaling` in kwargs but hasn't set it as attribute. For RoPE standardization you need to set `self.rope_parameters` in model's config.
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] vertex_tensorboard: dependency missing; using stub. (ModuleNotFoundError)
# W0620 16:27:02.131859 133646633308800 pyconfig.py:102] No config file provided, using default config mapping: /content/maxtext/src/maxtext/configs/base.yml
# ...

# %%
import jax
import gc
jax.clear_caches()
gc.collect()
# Out:
# 0

# %%
# !python3 -m maxtext.trainers.pre_train.train \
    model_name=qwen2.5-1.5b \
    steps=50 \
    dataset_type=synthetic \
    attention=dot_product \
    per_device_batch_size=1 \
    max_target_length=256 \
    enable_checkpointing=False \
    save_checkpoint_on_completion=False \
    skip_jax_distributed_system=True \
    base_output_directory=/content/metrics/gpu/scaled \
    run_name=qwen_1.5b_gpu_scaled
# Out:
# [transformers] DeepseekV32Config got `key=rope_scaling` in kwargs but hasn't set it as attribute. For RoPE standardization you need to set `self.rope_parameters` in model's config.
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] vertex_tensorboard: dependency missing; using stub. (ModuleNotFoundError)
# W0620 16:56:01.129879 134701444330112 pyconfig.py:102] No config file provided, using default config mapping: /content/maxtext/src/maxtext/configs/base.yml
# I0620 16:56:01.372803 134701444330112 max_utils.py:245] Skipping jax distributed system due to skip_jax_distributed_system=True flag.
# I0620 16:56:01.440650 134701444330112 xla_bridge.py:849] Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# ...

# %% [markdown]
# Task 3

# %%
# !python3 -m maxtext.trainers.pre_train.train \
    model_name=deepseek3-tiny \
    steps=50 \
    dataset_type=synthetic \
    attention=dot_product \
    per_device_batch_size=1 \
    max_target_length=256 \
    enable_checkpointing=False \
    save_checkpoint_on_completion=False \
    skip_jax_distributed_system=True \
    base_output_directory=/content/metrics/gpu/moe \
    run_name=deepseek_moe_gpu
# Out:
# [transformers] DeepseekV32Config got `key=rope_scaling` in kwargs but hasn't set it as attribute. For RoPE standardization you need to set `self.rope_parameters` in model's config.
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] mldiagnostics: dependency missing; using stub. (ModuleNotFoundError)
# [NO-OP] vertex_tensorboard: dependency missing; using stub. (ModuleNotFoundError)
# W0620 16:59:54.345684 133602753811072 pyconfig.py:102] No config file provided, using default config mapping: /content/maxtext/src/maxtext/configs/base.yml
# W0620 16:59:54.593146 133602753811072 pyconfig.py:294] tokenizer_path not found in HF_IDS in maxtext/src/maxtext/utils/globals.py.           Using the default src/maxtext/assets/tokenizers/tokenizer.llama2 instead.           Please pass tokenizer_path in your command if this is not intended.
# ...
